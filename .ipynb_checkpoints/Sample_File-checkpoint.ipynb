# %%
import pickle

# load the complete association matrix of query-page (pre-constructed)
association_mat = pickle.load(open('data/all_question_article_ratings.pkl','rb'))

# load the complete text-id dictionary of queries (pre-constructed)
question_id = pickle.load(open('data/all_questions_dict.pkl','rb'))

# load the complete text-features dictionary of queries (pre-constructed)
question_features = pickle.load(open('data/all_questions_title.pkl','rb'))

# load the complete url-id dictionary of pages (pre-constructed)
page_id = pickle.load(open('data/infowave_allintents_dict.pkl','rb'))

# load the complete url-features dictionary of pages (pre-constructed)
page_features = pickle.load(open('data/infowave_allintents_title.pkl','rb'))


def sample_by_query_id():
    # sample the data by query-id, 
    sample_threhold = 30

    ratings = []
    dict_i_mapping={}

    # construct the dictionaries 
    dict_url={}
    dict_title_embed={}    
    
    #filter out query-id and page-id by association matrix
    for x,y in association_mat:
        if (x<sample_threhold): # filter by query id
            ratings.append((x,y))
            
    all_q_ids = [x for (x,y) in ratings]
    all_i_ids = [y for (x,y) in ratings]            
    
    #print(all_i_ids)
    
    icount = 0

    for k,v in page_id.items():
        #print(k,v)
        if ((v[0] in all_i_ids) and (k in page_features)):
            print('appending')
            dict_url[k]=v[0]
            dict_title_embed[k]=page_features[k]
            
            if v[0] not in dict_i_mapping:
                dict_i_mapping[v[0]]=icount
                icount+=1
                
    #print(dict_i_mapping)
    
    new_ratings=[]

    # remap the page id to the sampled new ids 
    for x,y in ratings:
        new_ratings.append((x,dict_i_mapping[y]))
    
    
    # replace the rating association matrix with the one with new ID-mappings
    ratings = new_ratings

    # construct the dictionaries 
    dict_url={}
    dict_url_embed={}    

#     dict_question={}
#     dict_question_embed={}

    for k,v in page_id.items():
        if (v[0] in all_i_ids) and (k in page_features):

            dict_url[k]=dict_i_mapping[v[0]]
            dict_url_embed[k]=page_features[k]    
    
    pickle.dump(ratings,open('data/sample_by_page_questions_article_ratings.pkl','wb'))
    pickle.dump(dict_url,open('data/sample_by_page_page_dict.pkl','wb'))
    pickle.dump(dict_title_embed,open('data/sample_by_page_page_features.pkl','wb'))


def sample_by_page_id():
    # sample the data by page-id, here we limit a number of page ids,  only keep the page < 10
    sample_threhold = 10

    ratings=[]
    dict_question={}
    dict_question_embed={}

    dict_q_mapping={}
    dict_url={}
    dict_title={}

    for x,y in association_mat:
        if (y<sample_threhold): # filter by page id
            ratings.append((x,y))

            #print(x,y)

    all_q_ids = [x for (x,y) in ratings]
    all_i_ids = [y for (x,y) in ratings]

    icount = 0

    for k,v in question_id.items():
        if (v in all_q_ids) and (k in question_features):

            dict_question[k]=v
            dict_question_embed[k]=question_features[k]
            if v not in dict_q_mapping:
                dict_q_mapping[v]=icount
                icount+=1

    
    new_ratings=[]

    for x,y in ratings:
        new_ratings.append((dict_q_mapping[x],y))

    ratings = new_ratings

    dict_question={}
    dict_question_embed={}

    for k,v in question_id.items():
        if (v[0] in all_q_ids) and (k in question_features):

            dict_question[k]=dict_q_mapping[v]
            dict_question_embed[k]=question_features[k]

    pickle.dump(ratings,open('data/sample_by_question_questions_article_ratings.pkl','wb'))
    pickle.dump(dict_question,open('data/sample_by_question_questions_dict.pkl','wb'))
    pickle.dump(dict_question_embed,open('data/sample_by_question_questions_features.pkl','wb'))

    
sample_by_query_id()
# Out:
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/ProbRes/ProblemResolutionMatrices.jsp [0]
# appending
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/ContactVG/CntctClntsFaxPolicy.jsp [1]
# appending
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/Transact/IncomingWireNonRtrmtExist.jsp [2]
# appending
# http://oedesktop.vanguard.com/us/content/InfoWave/ComplianceManual/ESA/ESARules.jsp [3]
# appending
# http://oedesktop.vanguard.com/us/content/InfoWave/IRAServices/TransferRollover/ReturnRollIncrement.jsp [4]
# appending
# http://oedesktop.vanguard.com/us/content/InfoWave/IRAServices/TransferRollover/RolloverRules.jsp [5]
# appending
# http://oedesktop.vanguard.com/us/content/InfoWave/ComplianceManual/VGPolicy/IWNameChange.jsp [6]
# appending
# http://oedesktop.vanguard.com/us/content/InfoWave/IRACompliance/IRATransactions/RolloverGen.jsp [7]
# appending
# http://oedesktop.vanguard.com/us/content/InfoWave/IRAServices/TransferRollover/RolloverCertForm.jsp [8]
# appending
# http://oedesktop.vanguard.com/us/content/InfoWave/IRAServices/TransferRollover/RolloverCompanyStock.jsp [9]
# appending
# http://oedesktop.vanguard.com/us/content/InfoWave/IRAServices/TransferRollover/SettlementChecks.jsp [10]
# appending
# http://oedesktop.vanguard.com/us/content/InfoWave/IRACompliance/IRATransactions/IWAssetTransferGen.jsp [11]
# appending
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/PurchFunds/LostMissResearch.jsp [12]
# appending
# http://oedesktop.vanguard.com/us/content/InfoWave/IRACompliance/IRATransactions/IRARolloverDirect.jsp [13]
# appending
# http://oedesktop.vanguard.com/us/content/InfoWave/IRACompliance/TaxesForms/IWIRADistRequestForm.jsp [14]
# appending
# http://oedesktop.vanguard.com/us/content/InfoWave/IRAServices/TransferRollover/IndirectRollover.jsp [15]
# appending
# http://oedesktop.vanguard.com/us/content/InfoWave/IRACompliance/TaxesForms/IWLetterAcceptAssetTrans.jsp [16]
# appending
# http://oedesktop.vanguard.com/us/content/InfoWave/IRAServices/TransferRollover/RolloverSBS.jsp [17]
# appending
# http://oedesktop.vanguard.com/us/content/InfoWave/BrokerDealer/BrokerageRestrictedStock.jsp [18]
# appending
# http://oedesktop.vanguard.com/us/content/InfoWave/BrokerDealer/BrokerageResidualTransfer.jsp [19]
# http://oedesktop.vanguard.com/us/content/InfoWave/IRAServices/Roth/ConversionNonRothEmpPlan.jsp [20]
# http://oedesktop.vanguard.com/us/content/InfoWave/BrokerDealer/BrokerageTransfersUnlikeRegistrations.jsp [21]
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/Dept/RStoBDGLead.jsp [22]
# http://oedesktop.vanguard.com/us/content/InfoWave/ComplianceManual/VGPolicy/IWAcceptCheckPurch.jsp [23]
# http://oedesktop.vanguard.com/us/content/InfoWave/ComplianceManual/VGPolicy/IWSHAcctLegalFreeze.jsp [24]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/SpecOpts/DivCapGainEstablish.jsp [25]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/SpecOpts/DivCapGainTroubleFAQ.jsp [26]
# http://oedesktop.vanguard.com/us/content/InfoWave/BrokerDealer/BrokerageChangingDividendElections.jsp [27]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/AcctMaint/GenAddrssChngs15DayRedRes.jsp [28]
# http://oedesktop.vanguard.com/us/content/InfoWave/BrokerDealer/BrokerageDividendInterestReinvestmentProgram.jsp [29]
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/Stmts/SpecialTransConfHighlts.jsp [30]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/SpecOpts/DivCapGnChange.jsp [31]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/SpecOpts/DivCapGainRequiredNew.jsp [32]
# http://oedesktop.vanguard.com/us/content/InfoWave/BrokerDealer/BrokerageDividendInterestDividendEntitlement.jsp [33]
# http://oedesktop.vanguard.com/us/content/InfoWave/TaxManual/DivCapGains/IWDividendCalendar.jsp [34]
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/FundInfo/MPFs.jsp [35]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/SpecOpts/RPOOverview.jsp [36]
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/Stmts/AccountProfileConfirmMailing.jsp [37]
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/FundInfo/InternationalStats.jsp [38]
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/PurchFunds/AdmiralConversionNew.jsp [39]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/Transact/TransfersNonRetrmUnlike.jsp [40]
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/PurchFunds/AdmiralBackgroundNew.jsp [41]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/Transact/IWOptionsManualTransactionsUnlikeExchngsOverview.jsp [42]
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/PurchFunds/VBAMoneyMovementTrade.jsp [43]
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/PurchFunds/VBAMoneyMovementWithdraw.jsp [44]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/Transact/CrossPlatform.jsp [45]
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/PurchFunds/VBAMoneyMovement.jsp [46]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/Transact/CancelTradeVBA.jsp [47]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/Transact/ProcessExchangeWAVENew.jsp [48]
# http://oedesktop.vanguard.com/us/content/InfoWave/ComplianceManual/AcctPermission/IWLimitedAgent.jsp [49]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/Transact/ManualPurge1.jsp [50]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/AcctMaint/CIFMaint.jsp [51]
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/FundInfo/ChgCloseMergClosedFnd.jsp [52]
# http://oedesktop.vanguard.com/us/content/InfoWave/BrokerDealer/BrokerageETFConversion.jsp [53]
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/PurchFunds/AdmiralCriteria.jsp [54]
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/PurchFunds/RushSolutionsExistingIRA.jsp [55]
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/FundInfo/DistMethodDividends.jsp [56]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/SpecOpts/AESChangeMaintainNew.jsp [57]
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/PurchFunds/TrdDateExch.jsp [58]
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/PurchFunds/VBAMoneyMovementImpact.jsp [59]
# http://oedesktop.vanguard.com/us/content/InfoWave/IRACompliance/IRATransactions/IRAContribClientQues.jsp [60]
# http://oedesktop.vanguard.com/us/content/InfoWave/IRACompliance/TaxesForms/TaxReliefAct.jsp [61]
# http://oedesktop.vanguard.com/us/content/InfoWave/BrokerDealer/BrokerageIncomingTransfersInfoNeeded.jsp [62]
# http://oedesktop.vanguard.com/us/content/InfoWave/IRACompliance/IRATransactions/IWAssetTransferFromVG.jsp [63]
# http://oedesktop.vanguard.com/us/content/InfoWave/IRAServices/JobAids/RolloverChart.jsp [64]
# http://oedesktop.vanguard.com/us/content/InfoWave/IRAServices/TransferRollover/AssetTransferVBAEx.jsp [65]
# http://oedesktop.vanguard.com/us/content/InfoWave/BrokerDealer/BrokerageRescindTransfer.jsp [66]
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/ProbRes/MissedAssetTransfers.jsp [67]
# http://oedesktop.vanguard.com/us/content/InfoWave/IRAServices/TransferRollover/AssetTransferVBAInt.jsp [68]
# http://oedesktop.vanguard.com/us/content/InfoWave/IRAServices/TransferRollover/Roth401kRollover.jsp [69]
# http://oedesktop.vanguard.com/us/content/InfoWave/BrokerDealer/TrackYourTransfer.jsp [70]
# http://oedesktop.vanguard.com/us/content/InfoWave/BrokerDealer/BrokerageTransferFAQs.jsp [71]
# http://oedesktop.vanguard.com/us/content/InfoWave/IRACompliance/SpecialSituations/IWRemoveFundsTransfer.jsp [72]
# http://oedesktop.vanguard.com/us/content/InfoWave/BrokerDealer/BrokerageTransferTypes.jsp [73]
# http://oedesktop.vanguard.com/us/content/InfoWave/BrokerDealer/BrokerageCOOUGMA.jsp [74]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/Transact/RedmptnsLostMssngStopRep.jsp [75]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/Transact/WireTransmissionTime.jsp [76]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/Transact/InOutWiresUpgradVBA2.jsp [77]
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/PurchFunds/TrdDateIncmgWire.jsp [78]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/Transact/OneTimeWire.jsp [79]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/Transact/IncomingWireVerifyStatus.jsp [80]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/Transact/InOutWiresUpgradVBA.jsp [81]
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/Security/OneTimePasscodeClient.jsp [82]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/Transact/IncomingWireGenInfo.jsp [83]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/Transact/WireRedemptionIntl.jsp [84]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/Transact/WireRedemptionProcess.jsp [85]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/Transact/OneTimeWirePaperwork.jsp [86]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/SpecOpts/InternationalBankEstablish.jsp [87]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/Transact/WireRedemptionTA.jsp [88]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/Transact/RecallAmendTraceForm.jsp [89]
# http://oedesktop.vanguard.com/us/content/InfoWave/IRAServices/Distributions/OrderingRulesRoth.jsp [90]
# http://oedesktop.vanguard.com/us/content/InfoWave/TaxManual/VGTaxForms/IWInfoReprtdFrm5498.jsp [91]
# http://oedesktop.vanguard.com/us/content/InfoWave/IRACompliance/IRARules/IWTradIRAEligibility.jsp [92]
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/PurchFunds/TGIncomeLimit.jsp [93]
# http://oedesktop.vanguard.com/us/content/InfoWave/IRACompliance/IRARules/IWIRATypes.jsp [94]
# http://oedesktop.vanguard.com/us/content/InfoWave/IRAServices/JobAids/IRAServGlossary.jsp [95]
# http://oedesktop.vanguard.com/us/content/InfoWave/IRACompliance/IRATransactions/IWReqRolloverRed.jsp [96]
# http://oedesktop.vanguard.com/us/content/InfoWave/IRACompliance/SpecialSituations/IWEEContribAfterDeadline.jsp [97]
# http://oedesktop.vanguard.com/us/content/InfoWave/IRACompliance/IRATransactions/ExcessRemovalQA.jsp [98]
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/PurchFunds/TGCorrectIRAContrib.jsp [99]
# http://oedesktop.vanguard.com/us/content/InfoWave/IRACompliance/IRARules/IRAInvestVehicle.jsp [100]
# http://oedesktop.vanguard.com/us/content/InfoWave/IRACompliance/SpecialSituations/IWRemoveFundsIRAGen.jsp [101]
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/PurchFunds/TGContribGuide.jsp [102]
# http://oedesktop.vanguard.com/us/content/InfoWave/ComplianceManual/AcctPermission/IWAgentAuth.jsp [103]
# http://oedesktop.vanguard.com/us/content/InfoWave/IRACompliance/IRARules/IWCompensation.jsp [104]
# http://oedesktop.vanguard.com/us/content/InfoWave/IRACompliance/IRATransactions/IWTradRothContribLimits.jsp [105]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/SpecOpts/EBTWireTimetable.jsp [106]
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/Security/VoiceVerificationRedux3Enrollment.jsp [107]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/AutoOnline/OnlineSvcsVGcomWebPsswrdMaintReg.jsp [108]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/AutoOnline/OnlineSvcsVGcomRegRules.jsp [109]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/AutoOnline/SecurityCodes.jsp [110]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/AutoOnline/MobiIphone.jsp [111]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/AutoOnline/OnlineSvcsEnhancedWebSecTroub.jsp [112]
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/PurchFunds/OpenAccountQA.jsp [113]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/AutoOnline/MobileCheck.jsp [114]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/AutoOnline/VGcomGenerateTemp.jsp [115]
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/Security/AcctCallSecurityReqID.jsp [116]
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/Security/AcctCallSecurityAuth.jsp [117]
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/Security/OneTimePasscodeEligible.jsp [118]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/SpecOpts/BankingInfoVerificationHold.jsp [119]
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/Security/AcctPasswdCoreAccts.jsp [120]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/SpecOpts/MailOptDupStmtDes.jsp [121]
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/Security/KnowledgeBasedAuth.jsp [122]
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/Security/AcctCallSecurityOutcall.jsp [123]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/SpecOpts/CWRTroubleFAQ.jsp [124]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/SpecOpts/CWREstCrvrDelRstEst.jsp [125]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/SpecOpts/NSFCWRFlagship.jsp [126]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/SpecOpts/CWREstCrvrDelRstCrvr.jsp [127]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/SpecOpts/CWROptionPolicy.jsp [128]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/SpecOpts/CWROptDes.jsp [129]
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/StandOps/ProblemCaseJobAid.jsp [130]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/SpecOpts/CWRInsufficientFunds.jsp [131]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/Transact/RedmptnsMailUncollectd.jsp [132]
# http://oedesktop.vanguard.com/us/content/InfoWave/IRAServices/Inherited/SpouseAssumeTrustEstate.jsp [133]
# http://oedesktop.vanguard.com/us/content/InfoWave/ComplianceManual/TransferRedempt/IWUGMATransfer.jsp [134]
# http://oedesktop.vanguard.com/us/content/InfoWave/ComplianceManual/TransferRedempt/IWJointTransfer.jsp [135]
# http://oedesktop.vanguard.com/us/content/InfoWave/ComplianceManual/TransferRedempt/IWEstateTransfer.jsp [136]
# http://oedesktop.vanguard.com/us/content/InfoWave/ComplianceManual/TransferRedempt/IWIndivTransfer.jsp [137]
# http://oedesktop.vanguard.com/us/content/InfoWave/BrokerDealer/BrokerageGiftingSharesExternal.jsp [138]
# http://oedesktop.vanguard.com/us/content/InfoWave/ComplianceManual/VGPolicy/IWForeignInvestor.jsp [139]
# http://oedesktop.vanguard.com/us/content/InfoWave/BrokerDealer/BrokerageCOOJoint.jsp [140]
# http://oedesktop.vanguard.com/us/content/InfoWave/BrokerDealer/BrokerageCOOOverview.jsp [141]
# http://oedesktop.vanguard.com/us/content/InfoWave/ComplianceManual/TransferRedempt/IWTrustTransfer.jsp [142]
# http://oedesktop.vanguard.com/us/content/InfoWave/BrokerDealer/BrokerageCOOIndiv.jsp [143]
# http://oedesktop.vanguard.com/us/content/InfoWave/ComplianceManual/TransferRedempt/IWCorpProfCorpTransfer.jsp [144]
# http://oedesktop.vanguard.com/us/content/InfoWave/BrokerDealer/BrokerageCOOIRAProcessing.jsp [145]
# http://oedesktop.vanguard.com/us/content/InfoWave/BrokerDealer/BrokerageCOOTrust.jsp [146]
# http://oedesktop.vanguard.com/us/content/InfoWave/BrokerDealer/BrokerageCOOEstate.jsp [147]
# http://oedesktop.vanguard.com/us/content/InfoWave/TaxManual/TaxRsrcs/IWAvgCostServManCalc.jsp [148]
# http://oedesktop.vanguard.com/us/content/InfoWave/TaxManual/DivCapGains/CostBasisGeneral.jsp [149]
# http://oedesktop.vanguard.com/us/content/InfoWave/TaxManual/TaxRsrcs/AvgCostHandleCalls.jsp [150]
# http://oedesktop.vanguard.com/us/content/InfoWave/TaxManual/TaxRsrcs/AvgCostResolutionTimes.jsp [151]
# http://oedesktop.vanguard.com/us/content/InfoWave/TaxManual/TaxRsrcs/IWAvgCostServEligExcl.jsp [152]
# http://oedesktop.vanguard.com/us/content/InfoWave/TaxManual/TaxRsrcs/TACostBasisIneligibility.jsp [153]
# http://oedesktop.vanguard.com/us/content/InfoWave/TaxManual/DivCapGains/CostBasisDiscussions.jsp [154]
# http://oedesktop.vanguard.com/us/content/InfoWave/TaxManual/TaxRsrcs/CostBasis1099B.jsp [155]
# http://oedesktop.vanguard.com/us/content/InfoWave/TaxManual/TaxRsrcs/IWWashSaleRule.jsp [156]
# http://oedesktop.vanguard.com/us/content/InfoWave/TaxManual/TaxRsrcs/AvgCostRRSScripts.jsp [157]
# http://oedesktop.vanguard.com/us/content/InfoWave/TaxManual/TaxRsrcs/MinTax.jsp [158]
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/VGFees/TranscriptCurrentHist.jsp [159]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/AcctMaint/DOBUpdate.jsp [160]
# http://oedesktop.vanguard.com/us/content/InfoWave/TaxManual/TaxRsrcs/TaxStatusChange.jsp [161]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/SpecOpts/BankTransferForm.jsp [162]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/AcctMaint/DualCINergy.jsp [163]
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/StandOps/ClientProfileDef.jsp [164]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/AutoOnline/ClientEmail.jsp [165]
# http://oedesktop.vanguard.com/us/content/InfoWave/TaxManual/TaxID/IWW9Ovrw.jsp [166]
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/ContactVG/vgiformsjobaid.jsp [167]
# http://oedesktop.vanguard.com/us/content/InfoWave/ComplianceManual/Registrations/IWComplRegAttnyFact.jsp [168]
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/ContactVG/TelephnIntlCalls.jsp [169]
# http://oedesktop.vanguard.com/us/content/InfoWave/BrokerDealer/BrokerageConsolidatedTaxForm.jsp [170]
# http://oedesktop.vanguard.com/us/content/InfoWave/TaxManual/TaxRsrcs/IWTGTurboTax.jsp [171]
# http://oedesktop.vanguard.com/us/content/InfoWave/TaxManual/ProbRes/IWHowReqstCorrctdTaxFrm.jsp [172]
# http://oedesktop.vanguard.com/us/content/InfoWave/BrokerDealer/BrokerageUBTI.jsp [173]
# http://oedesktop.vanguard.com/us/content/InfoWave/TaxManual/VGTaxForms/IWFrm1099ROvrvw.jsp [174]
# http://oedesktop.vanguard.com/us/content/InfoWave/TaxManual/TaxRsrcs/IWHowReqPriorYrTaxFrms.jsp [175]
# http://oedesktop.vanguard.com/us/content/InfoWave/BrokerDealer/Brokerage1099Q.jsp [176]
# http://oedesktop.vanguard.com/us/content/InfoWave/TaxManual/Wthhldng/CanadaTax.jsp [177]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/Transact/ClientProfileCorrection.jsp [178]
# http://oedesktop.vanguard.com/us/content/InfoWave/TaxManual/TaxRsrcs/IWTGAvgCostREIT.jsp [179]
# http://oedesktop.vanguard.com/us/content/InfoWave/BrokerDealer/BrokerageConsolidated1099DIV.jsp [180]
# http://oedesktop.vanguard.com/us/content/InfoWave/IntForms/Paper/ClerEnvelopeLitReq.jsp [181]
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/Stmts/DocRequestsProspectPurge.jsp [182]
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/PurchFunds/PostUpgrade.jsp [183]
# http://oedesktop.vanguard.com/us/content/InfoWave/TaxManual/VGTaxForms/IWFrm1099RDistCodes.jsp [184]
# http://oedesktop.vanguard.com/us/content/InfoWave/BrokerDealer/Brokerage1099R.jsp [185]
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/FundInfo/FundIDDef.jsp [186]
# http://oedesktop.vanguard.com/us/content/InfoWave/TaxManual/VGTaxForms/IWInfoReprtdFrm1099B.jsp [187]
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/StandOps/PersonalPerformance.jsp [188]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/AutoOnline/KnowledgeBasedRegSteps.jsp [189]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/AutoOnline/OnlineSvcsVGcomWebPsswrdMaintBlk.jsp [190]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/AutoOnline/VGcomPreregEIN.jsp [191]
# http://oedesktop.vanguard.com/us/content/InfoWave/ComplianceManual/VGPolicy/DiminishedCapacity4.jsp [192]
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/PurchFunds/UpgradeRules.jsp [193]
# http://oedesktop.vanguard.com/us/content/InfoWave/ComplianceManual/AcctPermission/IWAgentIncapacitated.jsp [194]
# http://oedesktop.vanguard.com/us/content/InfoWave/ComplianceManual/DocumentsCerts/IWIndemCorpResolution.jsp [195]
# http://oedesktop.vanguard.com/us/content/InfoWave/ComplianceManual/AcctPermission/LimitedAccessOnline.jsp [196]
# http://oedesktop.vanguard.com/us/content/InfoWave/ComplianceManual/VGPolicy/IWIncarceratedPerson.jsp [197]
# http://oedesktop.vanguard.com/us/content/InfoWave/ComplianceManual/AcctPermission/IWInquiryAcess.jsp [198]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/AutoOnline/VGcomClientReset.jsp [199]
# http://oedesktop.vanguard.com/us/content/InfoWave/IntForms/NT/ClerRevokeLegDocAuthReq.jsp [200]
# http://oedesktop.vanguard.com/us/content/InfoWave/ComplianceManual/VGPolicy/DiminishedCapacity.jsp [201]
# http://oedesktop.vanguard.com/us/content/InfoWave/ComplianceManual/DocumentsCerts/IWTrusteeCertification.jsp [202]
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/Security/GrantAccessUpgrade.jsp [203]
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/Security/AcctFreezeAdd10day.jsp [204]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/AutoOnline/VGcomSharingCredentials.jsp [205]
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/Security/AcctCIPResources.jsp [206]
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/Security/AcctFreezeRemove.jsp [207]
# http://oedesktop.vanguard.com/us/content/InfoWave/ComplianceManual/VGPolicy/IWCompliancePledgeEstablish.jsp [208]
# http://oedesktop.vanguard.com/us/content/InfoWave/BrokerDealer/AssociatedStatusReporting.jsp [209]
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/Security/VoiceVerificationRedux1Description.jsp [210]
# http://oedesktop.vanguard.com/us/content/InfoWave/BrokerDealer/BrokerageUncollectedFunds.jsp [211]
# http://oedesktop.vanguard.com/us/content/InfoWave/IRAServices/TransferRollover/DefaultDirectRollover.jsp [212]
# http://oedesktop.vanguard.com/us/content/InfoWave/ComplianceManual/VGPolicy/IWPatriotActCIP.jsp [213]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/Transact/RedmptnsChangeIndicator.jsp [214]
# http://oedesktop.vanguard.com/us/content/InfoWave/TaxManual/Wthhldng/IWStateTxWthhldngOvrvw.jsp [215]
# http://oedesktop.vanguard.com/us/content/InfoWave/ComplianceManual/Registrations/IWComplRegUGMA.jsp [216]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/AcctMaint/GenAddrssChngsJoint.jsp [217]
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/Security/ClientPrivCompromise.jsp [218]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/AcctMaint/GenAddrssChngsSeasonal.jsp [219]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/AcctMaint/GenAddrssChngsTeleOnln.jsp [220]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/AcctMaint/PrimaryAddressIndicator.jsp [221]
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/Security/VoiceVerificationRedux4Authentication.jsp [222]
# http://oedesktop.vanguard.com/us/content/InfoWave/IRAServices/Beneficiaries/BeneficiaryOverview.jsp [223]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/AcctMaint/MilitaryAddress.jsp [224]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/SpecOpts/UpdatedBankAuthNegConsent.jsp [225]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/SpecOpts/AWPAWPDes.jsp [226]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/SpecOpts/AWPDeleteCancel.jsp [227]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/SpecOpts/BankingInfoAddOwnersAuth.jsp [228]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/SpecOpts/AIPTroubleFAQ.jsp [229]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/SpecOpts/AESEstCryvrDelRstReq.jsp [230]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/SpecOpts/AWPEstablish.jsp [231]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/SpecOpts/AIPEstablish.jsp [232]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/SpecOpts/AESAESDes.jsp [233]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/SpecOpts/AIPChangeMaintain.jsp [234]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/SpecOpts/DirDepEstCrvDelRstEstRst.jsp [235]
# http://oedesktop.vanguard.com/us/content/InfoWave/TransferAgency/TAFTP.jsp [236]
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/Stmts/RealTimeAlerts.jsp [237]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/SpecOpts/AWPChangeMaintain.jsp [238]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/SpecOpts/AIPDeleteCancel.jsp [239]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/SpecOpts/AESDeleteCancel.jsp [240]
# http://oedesktop.vanguard.com/us/content/InfoWave/IntForms/NT/ClerGILtrAVT1.jsp [241]
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/Dept/AssetVerifRequest.jsp [242]
# http://oedesktop.vanguard.com/us/content/InfoWave/IntForms/NT/ClerGILtr.jsp [243]
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/StandOps/AWDCopyReq.jsp [244]
# http://oedesktop.vanguard.com/us/content/InfoWave/IRAServices/WealthTransfer/WTSCorresp.jsp [245]
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/Stmts/TotalReturnChart.jsp [246]
# http://oedesktop.vanguard.com/us/content/InfoWave/IRAServices/JobAids/IRACustAcctAgree.jsp [247]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/SpecOpts/MailOptOrderWAVEHow.jsp [248]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/SpecOpts/BankingInfoEstablish.jsp [249]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/SpecOpts/BankingInfoChangeMaintain.jsp [250]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/SpecOpts/BankingInfoBAP.jsp [251]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/SpecOpts/BankingInfoAuthorityAddChangeDelete.jsp [252]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/SpecOpts/BankingInfoMicro.jsp [253]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/SpecOpts/BankingInfoRRS.jsp [254]
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/PurchFunds/AdditionalPurchasesNew.jsp [255]
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/ProbRes/ACHRejectIssues.jsp [256]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/AutoOnline/EDeliveryEligibility.jsp [257]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/Transact/TransactionLinks.jsp [258]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/AutoOnline/OutsideInvestments.jsp [259]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/AutoOnline/KnowledgeBasedReregSteps.jsp [260]
# http://oedesktop.vanguard.com/us/content/InfoWave/BrokerDealer/BrokerageNAReqAssocPerson.jsp [261]
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/PurchFunds/OAAVBAExternal.jsp [262]
# http://oedesktop.vanguard.com/us/content/InfoWave/ComplianceManual/Registrations/IWComplRegCust.jsp [263]
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/StandOps/AWDOutcalls.jsp [264]
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/PurchFunds/OAAVBAInternal.jsp [265]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/AutoOnline/OnlineSvcsVGcomEmail.jsp [266]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/AutoOnline/OnlineSvcsVGcomNewAcct.jsp [267]
# http://oedesktop.vanguard.com/us/content/InfoWave/BrokerDealer/UpgradeVBAExternal.jsp [268]
# http://oedesktop.vanguard.com/us/content/InfoWave/ComplianceManual/DocumentsCerts/IWTrustInstrument.jsp [269]
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/PurchFunds/OpenAccountDraft.jsp [270]
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/PurchFunds/RushSolutionsNewIRA.jsp [271]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/AutoOnline/LiteProspect.jsp [272]
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/PurchFunds/VBAOAA.jsp [273]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/Transact/TransfersInKindNonRetrm.jsp [274]
# http://oedesktop.vanguard.com/us/content/InfoWave/BrokerDealer/BrokerageGiftingShares.jsp [275]
# http://oedesktop.vanguard.com/us/content/InfoWave/BrokerDealer/OutgoingACATTrans.jsp [276]
# http://oedesktop.vanguard.com/us/content/InfoWave/BrokerDealer/OutgoingNonACATTrans.jsp [277]
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/PurchFunds/ReqMinNonIRA.jsp [278]
# http://oedesktop.vanguard.com/us/content/InfoWave/SBS/SIMPLEIRA/SIMPLEATIRAForm.jsp [279]
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/Stmts/SpecialIBMHighlts.jsp [280]
# http://oedesktop.vanguard.com/us/content/InfoWave/BrokerDealer/SubPenny.jsp [281]
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/PurchFunds/DirectBuy.jsp [282]
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/StandOps/AWDNavigate.jsp [283]
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/PurchFunds/EBTPurchase.jsp [284]
# http://oedesktop.vanguard.com/us/content/InfoWave/BrokerDealer/VBASplitCheck.jsp [285]
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/ContactVG/MailIncomAdd.jsp [286]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/Transact/RedmptnsMailTeleMail.jsp [287]
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/PurchFunds/BuyPayMeth.jsp [288]
# http://oedesktop.vanguard.com/us/content/InfoWave/BrokerDealer/AgingSharesMargin.jsp [289]
# http://oedesktop.vanguard.com/us/content/InfoWave/IRACompliance/IRATransactions/IRAContribProcessing.jsp [290]
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/ContactVG/PASManagedTransactions.jsp [291]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/Transact/RedemptionCheckExample.jsp [292]
# http://oedesktop.vanguard.com/us/content/InfoWave/BrokerDealer/BrokerageOrdersSecuritiesTransactionFee.jsp [293]
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/Security/VoiceVerificationRedux2Positioning.jsp [294]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/Transact/RedemptionSpecialPayeeElig.jsp [295]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/SpecOpts/FedExTrackingOutgoing.jsp [296]
# http://oedesktop.vanguard.com/us/content/InfoWave/BrokerDealer/CorporateActionWorthlessSecurities.jsp [297]
# http://oedesktop.vanguard.com/us/content/InfoWave/BrokerDealer/CloseBrokerage.jsp [298]
# http://oedesktop.vanguard.com/us/content/InfoWave/TransferAgency/TAFTPCRFQA.jsp [299]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/AutoOnline/EDeliveryFAQ.jsp [300]
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/Stmts/HouseholdState.jsp [301]
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/Stmts/QuartMailings.jsp [302]
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/Stmts/QuartDescrip.jsp [303]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/SpecOpts/MailOptDupStmtCrvChng.jsp [304]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/SpecOpts/MailOptDupStmtDel.jsp [305]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/AutoOnline/EDeliveryGCA.jsp [306]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/SpecOpts/MailOptDupStmtEst.jsp [307]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/AutoOnline/EDeliveryTrouble.jsp [308]
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/Stmts/SpecialCWRActivDescrip.jsp [309]
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/PurchFunds/VBAPaperwork.jsp [310]
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/PurchFunds/UpgradeOptions.jsp [311]
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/PurchFunds/UpgradeOffer.jsp [312]
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/PurchFunds/UpgradeOverview.jsp [313]
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/PurchFunds/MergeExistingVBA.jsp [314]
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/PurchFunds/UpgradeFallout.jsp [315]
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/ContactVG/VBATransitionPositioning.jsp [316]
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/PurchFunds/UpgradeTimeline.jsp [317]
# http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/ContactVG/VBATransitionOverview.jsp [318]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/AutoOnline/OnlineSvcsEnhancedWebResetSec.jsp [319]
# http://oedesktop.vanguard.com/us/content/InfoWave/OptsManual/Transact/TechnicalIssues.jsp [320]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d1da9ad113e6> in <module>
#     135
#     136
# --> 137 sample_by_query_id()
#
# <ipython-input-1-d1da9ad113e6> in sample_by_query_id()
#      77
#      78     pickle.dump(ratings,open('data/sample_by_page_questions_article_ratings.pkl','wb'))
# ---> 79     pickle.dump(dict_question,open('data/sample_by_page_page_dict.pkl','wb'))
#      80     pickle.dump(dict_question_embed,open('data/sample_by_page_page_features.pkl','wb'))
#      81
#
# NameError: name 'dict_question' is not defined

# %%
page_id = pickle.load(open('data/sample_by_page_page_dict.pkl','rb'))
page_features = pickle.load(open('data/sample_by_page_page_features.pkl','rb'))

# %%
page_id
# Out:
# {'3 Rollovers, 1 was Roth but went into a pretax account. How to fix?': 0,
#  'can client fax/msg rollover certificaiton letter?': 1,
#  'Can client have a rollover wired into Vanguard?': 2,
#  'Can client move money from ESA to another type of account?': 3,
#  'Can client return Indirect rollover in increments?': 4,
#  'can rollover go into any acct?': 5,
#  'can send OATS with the rollover check?': 6,
#  'Can we accept a direct rollover check without an account number on it?': 7,
#  'can we fax in rollover cert letter': 8,
#  'can we fill out the tsp 60 form?': 9,
#  'can we rollover a 401k in kind': 10,
#  'client did an outgoing rollover and said there was a from we were supposed to sign and we didnt do it': 11,
#  'Do we need to get the name change done first?': 12,
#  'How can we accept a name variation on a rollover check?': 13,
#  'We sent the D/r check to the TSP but did not complete the attached TSP form 60 according to what they received which is preventing them from accepting the check, how to fix the error?': 14,
#  'What do we do if a rollover coming into clients account is not his?': 15,
#  'who handles this Rollover certification?': 16,
#  'will we fill out paperwork': 17,
#  "client's dividend didn't pay correctly": 18,
#  'How to do a rollover of company stock': 19,
#  'How to get VG to complete AXA paperwork?': 20,
#  'can the s/o wire into the account': 21,
#  'incoming wire to existing VBA account': 22,
#  'should client list Chase bank as bank for wire': 23,
#  'what is required to do an incoming wire?': 24,
#  'can you fax in name change form': 25,
#  'Client changed first and last name, does she need 2 forms of proof, one for first, one for last name?': 26,
#  'Client has a marriage cert and wants to use it to change her married name to maiden name. Will we allow that as backup?': 27,
#  'client requests are considered a name change and would require a Name Change form': 28,
#  'Client wants name change for UTMA for minor how can they do it?': 29,
#  "client's last name is spelled incorrectly on proespct ID- how to update": 30,
#  'does client need to complete name change in order to open account with a profile in her maiden name': 31,
#  'How can a client change their name back to ttheir maiden name if they cannot obtain an MSG?': 32,
#  'How can we capitalize the letter in clients last name?': 33,
#  'how do i name change a clients ugma account?': 34,
#  'How do we fix the middle initial?': 35,
#  'how to fix name by one letter and by name': 36,
#  "How to get client's name corrected if they accidentally put an extra letter?": 37,
#  'How to handle this name change due to marriage?': 38,
#  'middle name to middle initial on name change form': 39,
#  'spelling out middle initial can we do it?': 40,
#  "What do we do if the client can't get an MSG to do a name change form?": 41,
#  'When will we mail the client back her marriage cert': 42,
#  'Will difference in name be an issue?': 43,
#  'can s/h fax address change form?': 44,
#  'Cust sending in ESA Change form to transfer ESA to new minor, Cust is staying the same, since we have his SSN on file, can he just put the last 4?': 45,
#  'Can a transfer request for trust account be faxed?': 46,
#  'How can they send this rollover form?': 47,
#  'how to request corresp letter for at redemption ?': 48,
#  'What happwns for non education distributsions from an ESA?': 49}

# %%
a='http://oedesktop.vanguard.com/us/content/InfoWave/AssocHbk/ProbRes/ProblemResolutionMatrices.jsp'
a in page_features
# Out:
# True
